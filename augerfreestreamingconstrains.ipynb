# %%
#this code will serve to calculate the relationship between \sigma_x and M_x for auger. Upon successfully doing this, we will 
# add in the code to produce the macro constraint plots and plot the exclusion region using a polygon plot.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import lambertw
from scipy.special import erf

placeholder = 0.0
Mx=0
p=10
Mmax = []
Smin = [] #array of all sigma_x values
v=[]
for y in range(0,3):

    for i in range(1,p):
        sigmax = i*10**-(6-y)
    
        for j in range(0,6):
            vx = 170 + j*50 #setting macro speed
            z=2.5*lambertw(3.16*10**16*(sigmax)**3*(vx/250)**6)
        #z=10*lambertw(1.6*10**17*(sigmax)**2*(vx/250)**4)
            k=np.real(z)
            if k >20:
                k=20
            if k<1:
                k=0
            Mx = 1.2 * (k)**2
            if vx <230:
                Mx=Mx*(1-(-1.95313*10**9 + 1.95312*10**9*np.exp(-((-170 + vx)**2/62500)) + (1.17702*10**9 - 6.92365*10**6*vx)*erf(0.68 - 0.004*vx))*(2.407*10**-9))
            if vx >230:
                Mx=Mx*(1-(6.1501*10**8*np.exp((0.00544 - 0.000016*vx)*vx) - 8.37805*10**8*np.exp(-(((-460 + vx)*vx)/62500))+ 
                    6.1501*10**8*np.exp(-(((-340 + vx)*vx)/62500)) + (1.17702*10**9 - 6.92365*10**6*vx)*erf(0.68 - 0.004*vx) 
                       + (1.59244*10**9 - 6.92365*10**6 *vx)*erf((-230 + vx)/250))*(2.407*10**-9))
            if Mx > placeholder:
                placeholder = Mx
#         print(placeholder,Mx)
           
        Mmax.append(placeholder)
        Smin.append(sigmax)
        
print(Mmax,Smin)
# Out:
# [1.0309949387644994, 9.89700668229302, 23.89436999160289, 39.28949373802332, 54.74704200738964, 69.80261694461089, 84.30081952095443, 98.20516751831019, 111.52697742721182, 124.29638395935322, 229.00997167046378, 312.9948396858257, 383.372341329184, 414.158302175381, 444.86638730960914, 444.86638730960914, 472.42485634107396, 472.42485634107396, 472.42485634107396, 480.0115536, 480.0115536, 480.0115536, 480.0115536, 480.0115536, 480.0115536, 480.0115536, 480.0115536] [1e-06, 2e-06, 3e-06, 4e-06, 4.9999999999999996e-06, 6e-06, 7e-06, 8e-06, 9e-06, 1e-05, 2e-05, 3.0000000000000004e-05, 4e-05, 5e-05, 6.000000000000001e-05, 7.000000000000001e-05, 8e-05, 9e-05, 0.0001, 0.0002, 0.00030000000000000003, 0.0004, 0.0005, 0.0006000000000000001, 0.0007, 0.0008, 0.0009000000000000001]

# %%
augersmall = [[0.0]*2 for i in range(22)]
for i in range(0,22):
    augersmall[i][0]=Mmax[i]
    augersmall[i][1]=Smin[i]
print(augersmall)
# Out:
# [[1.0309949387644994, 1e-06], [9.89700668229302, 2e-06], [23.89436999160289, 3e-06], [39.28949373802332, 4e-06], [54.74704200738964, 4.9999999999999996e-06], [69.80261694461089, 6e-06], [84.30081952095443, 7e-06], [98.20516751831019, 8e-06], [111.52697742721182, 9e-06], [124.29638395935322, 1e-05], [229.00997167046378, 2e-05], [312.9948396858257, 3.0000000000000004e-05], [383.372341329184, 4e-05], [414.158302175381, 5e-05], [444.86638730960914, 6.000000000000001e-05], [444.86638730960914, 7.000000000000001e-05], [472.42485634107396, 8e-05], [472.42485634107396, 9e-05], [472.42485634107396, 0.0001], [480.0115536, 0.0002], [480.0115536, 0.00030000000000000003], [480.0115536, 0.0004]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import lambertw
from scipy.special import erf
vx=25
placeholder = 0.0
Mx=0
p=2
Mmax = []
Smin = [] #array of all sigma_x values
v=[]
for y in range(0,1):

    for i in range(1,p):
        sigmax = 9.42*10**-7#i*10**-(7-y)
    
        for j in range(0,6):
            vx = 170 + j*50 #setting macro speed
            z=2.5*lambertw(3.16*10**16*(sigmax)**3*(vx/250)**6)
        #z=10*lambertw(1.6*10**17*(sigmax)**2*(vx/250)**4)
            k=np.real(z)
            if k >20:
                k=20
            if k<1:
                k=0
            Mx = 24*1.2 * (k)**2
            if vx <230:
                Mx=Mx*(1-(-1.95313*10**9 + 1.95312*10**9*np.exp(-((-170 + vx)**2/62500)) + (1.17702*10**9 - 6.92365*10**6*vx)*erf(0.68 - 0.004*vx))*(2.407*10**-9))
            if vx >230:
                Mx=Mx*(1-(6.1501*10**8*np.exp((0.00544 - 0.000016*vx)*vx) - 8.37805*10**8*np.exp(-(((-460 + vx)*vx)/62500))+ 
                    6.1501*10**8*np.exp(-(((-340 + vx)*vx)/62500)) + (1.17702*10**9 - 6.92365*10**6*vx)*erf(0.68 - 0.004*vx) 
                       + (1.59244*10**9 - 6.92365*10**6 *vx)*erf((-230 + vx)/250))*(2.407*10**-9))
            
#             Mx = Mx * (1 + 0.00451352*vx*np.exp(-(vx**2/62500)) - erf(vx/250)) #cdf

            if Mx > placeholder:
                placeholder = Mx
#         print(placeholder,Mx)
           
        Mmax.append(placeholder)
        Smin.append(sigmax)
        
print(Mmax,Smin)
# Out:
# [0.0] [9.419999999999999e-07]

# %%
augerbig = [[0.0]*2 for i in range(34)]
# print(np.size(augersmall))
for i in range(0,33):
    augerbig[i][0]=Mmax[i]
    augerbig[i][1]=Smin[i]
print(augerbig)
# Out:
# [[0.0, 1e-07], [0.0, 2e-07], [0.0, 3e-07], [0.0, 4e-07], [0.0, 5e-07], [0.0, 6e-07], [0.0, 7e-07], [0.0, 8e-07], [0.0, 9e-07], [24.650418627900166, 1e-06], [236.6309946914056, 2e-06], [571.2988502628216, 3e-06], [939.3862490548685, 4e-06], [1308.966177601821, 4.9999999999999996e-06], [1668.9351851422146, 6e-06], [2015.577781940261, 7e-06], [2348.0217018818657, 8e-06], [2666.537514897651, 9e-06], [2971.8457223504793, 1e-05], [5475.479519235515, 2e-05], [7488.588484797514, 3.0000000000000004e-05], [9172.412246634243, 4e-05], [9912.551980873777, 5e-05], [10647.525754252905, 6.000000000000001e-05], [10647.525754252905, 7.000000000000001e-05], [11308.92901100806, 8e-05], [11308.92901100806, 9e-05], [11308.92901100806, 0.0001], [11520.277286399998, 0.0002], [11520.277286399998, 0.00030000000000000003], [11520.277286399998, 0.0004], [11520.277286399998, 0.0005], [11520.277286399998, 0.0006000000000000001], [0.0, 0.0]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import erf

placeholder = 0.0
Mx=0
p=10
Mmax = []
Smin = [] #array of all sigma_x values
v=[]
for j in range(0,21):
    vx = 170 + j*50 #setting macro speed
    sigmax=(6.7*10**-16*(250/vx)**6)**(1/3.0)
    if vx <230:
        Mx=5.5*10**6*(1-(-1.95313*10**9 + 1.95312*10**9*np.exp(-((-170 + vx)**2/62500)) + (1.17702*10**9 - 6.92365*10**6*vx)*erf(0.68 - 0.004*vx))/((np.pi*250**2)**1.5*(60)))
    if vx >230:
        Mx=5.5*10**6*(1-(6.1501*10**8*np.exp((0.00544 - 0.000016*vx)*vx) - 8.37805*10**8*np.exp(-(((-460 + vx)*vx)/62500))+ 
            6.1501*10**8*np.exp(-(((-340 + vx)*vx)/62500)) + (1.17702*10**9 - 6.92365*10**6*vx)*erf(0.68 - 0.004*vx) 
                + (1.59244*10**9 - 6.92365*10**6 *vx)*erf((-230 + vx)/250))*(4*np.pi/((np.pi*250**2)**1.5*(60))))

    if Mx <0:
        Mx=0
    Mmax.append(Mx)
    Smin.append(sigmax)
        
print(Mmax,Smin)
# Out:
# [5500010.535777831, 5499470.134832158, 5399219.515059308, 5083417.986504935, 4493264.409916191, 3685334.116545996, 2787731.573761691, 1939235.9798781779, 1239115.3509449656, 727065.6569064545, 391815.88356178754, 193991.90947502453, 88276.93537542058, 36933.53027001961, 14209.07715775438, 5024.262964388126, 1628.5333115838018, 478.63756823718353, 121.59773383862982, 19.85679553373476, 0] [1.8923745940383394e-05, 1.1299509456138018e-05, 7.502006278149246e-06, 5.340783766377735e-06, 3.994859442491453e-06, 3.1003189210718823e-06, 2.4757639550795837e-06, 2.022545331646006e-06, 1.683275646897753e-06, 1.422726997078772e-06, 1.218303091283315e-06, 1.0549696328647376e-06, 9.224089351949403e-07, 8.133495801265319e-07, 7.225475725684767e-07, 6.461439717356806e-07, 5.812480153864172e-07, 5.256596094550942e-07, 4.776803718028475e-07, 4.3598234827573353e-07, 3.9951512723871726e-07]

# %%
JEM = [[0.0]*2 for i in range(21)]
# print(np.size(augersmall))
for i in range(0,21):
    JEM[i][0]=Mmax[i]
    JEM[i][1]=Smin[i]
print(JEM)
# Out:
# [[5500010.535777831, 1.8923745940383394e-05], [5499470.134832158, 1.1299509456138018e-05], [5399219.515059308, 7.502006278149246e-06], [5083417.986504935, 5.340783766377735e-06], [4493264.409916191, 3.994859442491453e-06], [3685334.116545996, 3.1003189210718823e-06], [2787731.573761691, 2.4757639550795837e-06], [1939235.9798781779, 2.022545331646006e-06], [1239115.3509449656, 1.683275646897753e-06], [727065.6569064545, 1.422726997078772e-06], [391815.88356178754, 1.218303091283315e-06], [193991.90947502453, 1.0549696328647376e-06], [88276.93537542058, 9.224089351949403e-07], [36933.53027001961, 8.133495801265319e-07], [14209.07715775438, 7.225475725684767e-07], [5024.262964388126, 6.461439717356806e-07], [1628.5333115838018, 5.812480153864172e-07], [478.63756823718353, 5.256596094550942e-07], [121.59773383862982, 4.776803718028475e-07], [19.85679553373476, 4.3598234827573353e-07], [0, 3.9951512723871726e-07]]

# %%
import numpy as np

placeholder = 0.0
Mx=0
p=10
Mmax = []
Smin = [] #array of all sigma_x values
v=[]
for j in range(0,21):
    vx = 170 + j*50 #setting macro speed
    
    sigmax=(6.7*10**-16*(250/vx)**6)**(1/3.0)
    if vx <230:
        Mx=5.5*10**6*(1-(-1.95313*10**9 + 1.95312*10**9*np.exp(-((-170 + vx)**2/62500)) + (1.17702*10**9 - 6.92365*10**6*vx)*erf(0.68 - 0.004*vx))/((np.pi*250**2)**1.5*(60)))
    if vx >230:
        Mx=5.5*10**6*(1-(6.1501*10**8*np.exp((0.00544 - 0.000016*vx)*vx) - 8.37805*10**8*np.exp(-(((-460 + vx)*vx)/62500))+ 
            6.1501*10**8*np.exp(-(((-340 + vx)*vx)/62500)) + (1.17702*10**9 - 6.92365*10**6*vx)*erf(0.68 - 0.004*vx) 
                + (1.59244*10**9 - 6.92365*10**6 *vx)*erf((-230 + vx)/250))*(4*np.pi/((np.pi*250**2)**1.5*(60))))
#     Mx = 5.5*10**6 * (1 + 0.00451352*vx*np.exp(-(vx**2/62500)) - erf(vx/250)) #cdf
    if Mx <0:
        Mx=0
    Mmax.append(Mx)
    Smin.append(sigmax)
        
print(Mmax,Smin)
