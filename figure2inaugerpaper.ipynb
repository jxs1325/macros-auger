# %%
#auger plot for SNR of blackbody number of photons for various values of D

from scipy.interpolate import interp1d
import io
import csv
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
import os

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)
x=np.logspace(-7,2)
# x0D1=np.logspace(-9,-5.26)
# x0D2=np.logspace(-9,-5.22)
# x0D5=np.logspace(-9,-5.10)
x0D10=np.logspace(-9,-4.89)
# x0D20=np.logspace(-9,-4.43)
# x1D1=np.logspace(-5.26,-2.60)
# x1D2=np.logspace(-5.22,-2.55)
# x1D5=np.logspace(-5.10,-2.40)
x1D10=np.logspace(-4.89,-2.10)
# x1D20=np.logspace(-4.43,-1.52)
# x2D1=np.logspace(-2.60,4.43)
# x2D2=np.logspace(-2.55,4.52)
# x2D5=np.logspace(-2.40,4.78)
x2D10=np.logspace(-2.10,5.20)
# x2D20=np.logspace(-1.52,6.08)
# x3D1=np.logspace(4.43,7)
# x3D2=np.logspace(4.52,7)
# x3D5=np.logspace(4.78,7)
# x3D10=np.logspace(5.20,7)
# x3D20=np.logspace(6.08,7)
#X-axis
ax.set_xlabel('$\sigma_\t{X}$ [cm$^{2}$]',fontsize=12)
ax.set_xlim([x.min(),x.max()])

#Y-axis
ymin=10**0
ymax=10**10
ax.set_ylim([ymin,ymax])
ax.set_ylabel('$N_{\gamma}$',fontsize=12)
#SNR = 5
# ax.loglog(x,5*x**0,'k',markersize=4,color='k',lw=1,zorder=0,linestyle='dashed',label='SNR = 5')

#following apply to auger for FS one bin

# ax.loglog(x0, ((6*10**20*x0**2/20)/(1+(2*10**-16*20)/(x0**2)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
# ax.loglog(x0, ((6*10**20*x0**2/10)/(1+(2*10**-16*10)/(x0**2)))**0.5, 'k', markersize=4, color='b',lw=1,zorder=0)
# ax.loglog(x0, ((6*10**20*x0**2/5)/(1+(2*10**-16*5)/(x0**2)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
# ax.loglog(x0, ((6*10**20*x0**2/2)/(1+(2*10**-16*2)/(x0**2)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
# ax.loglog(x0, ((6*10**20*x0**2/1)/(1+(2*10**-16*1)/(x0**2)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)

# ax.loglog(x0D20, (0.25)**0.5*((10**21*np.exp(-0.4*20)*x0D20**3/20)/(1+(4*10**-16*20*np.exp(0.4*20))/(x0D20**3)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
ax.loglog(x0D10, (0.5*10**21*np.exp(-0.4*10)*x0D10**3/10), 'k', markersize=4, color='b',lw=1,zorder=0)
# ax.loglog(x0D5, (0.25)**0.5*((10**21*np.exp(-0.4*5)*x0D5**3/5)/(1+(4*10**-16*5*np.exp(0.4*5))/(x0D5**3)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
# ax.loglog(x0D2, (0.25)**0.5*((10**21*np.exp(-0.4*2)*x0D2**3/2)/(1+(4*10**-16*2*np.exp(0.4*2))/(x0D2**3)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
# ax.loglog(x0D1, (0.25)**0.5*((10**21*np.exp(-0.4*1)*x0D1**3/1)/(1+(4*10**-16*1*np.exp(0.4*1))/(x0D1**3)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)

#following apply to auger from 10^-7 to 9x10^7
# ax.loglog(x1, ((3.111*10**31*x1**3.531/20)/(1+(3.214*10**-27*20)/(x1**3.531)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
# ax.loglog(x1, ((3.111*10**31*x1**3.531/10)/(1+(3.214*10**-27*10)/(x1**3.531)))**0.5, 'k', markersize=4, color='b',lw=1,zorder=0)
# ax.loglog(x1, ((3.111*10**31*x1**3.531/5)/(1+(3.214*10**-27*5)/(x1**3.531)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
# ax.loglog(x1, ((3.111*10**31*x1**3.531/2)/(1+(3.214*10**-27*2)/(x1**3.531)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
# ax.loglog(x1, ((3.111*10**31*x1**3.531/1)/(1+(3.214*10**-27*1)/(x1**3.531)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)

# ax.loglog(x1D20, (0.25)**0.5*((5*10**15*np.exp(-0.3*20)*x1D20**2/20)/(1+(8*10**-11*20*np.exp(0.3*20))/(x1D20**2)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
ax.loglog(x1D10, (0.5*5*10**15*np.exp(-0.3*10)*x1D10**2/10), 'k', markersize=4, color='b',lw=1,zorder=0)
# ax.loglog(x1D5, (0.25)**0.5*((5*10**15*np.exp(-0.3*5)*x1D5**2/5)/(1+(8*10**-11*5*np.exp(0.3*5))/(x1D5**2)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
# ax.loglog(x1D2, (0.25)**0.5*((5*10**15*np.exp(-0.3*2)*x1D2**2/2)/(1+(8*10**-11*2*np.exp(0.3*2))/(x1D2**2)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
# ax.loglog(x1D1, (0.25)**0.5*((5*10**15*np.exp(-0.3*1)*x1D1**2/1)/(1+(8*10**-11*1*np.exp(0.3*1))/(x1D1**2)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)

#following apply to auger from 3x10^-7 to 4x10^-3

# ax.loglog(x2, ((1.63*10**19*x2**1.5/20)/(1+(6.1*10**-15*20)/(x2**1.5)))**0.5, 'k', markersize=4, color='g',lw=1,label='SNR D=20km',zorder=0)
# ax.loglog(x2, ((1.63*10**19*x2**1.5/10)/(1+(6.1*10**-15*10)/(x2**1.5)))**0.5, 'k', markersize=4, color='b',lw=1,label='SNR D=10km',zorder=0)
# ax.loglog(x2, ((1.63*10**19*x2**1.5/5)/(1+(6.1*10**-15*5)/(x2**1.5)))**0.5, 'k', markersize=4, color='r',lw=1,label='SNR D=5km',zorder=0)
# ax.loglog(x2, ((1.63*10**19*x2**1.5/2)/(1+(6.1*10**-15*2)/(x2**1.5)))**0.5, 'k', markersize=4, color='m',lw=1,label='SNR D=2km',zorder=0)
# ax.loglog(x2, ((1.63*10**19*x2**1.5/1)/(1+(6.1*10**-15*1)/(x2**1.5)))**0.5, 'k', markersize=4, color='c',lw=1,label='SNR D=1km',zorder=0)

# ax.loglog(x2D20, (0.25)**0.5*((5*10**7*np.exp(0.1*20)*x2D20**-1/20)/(1+(8*10**-3*20*np.exp(-0.1*20))/(x2D20**-1)))**0.5, 'k', markersize=4, color='g',lw=1,label='SNR D=20km',zorder=0)
ax.loglog(x2D10, (0.5*5*10**7*np.exp(0.1*10)*x2D10**-1/10), 'k', markersize=4, color='b',lw=1,label='Auger',zorder=0)
# ax.loglog(x2D5, (0.25)**0.5*((5*10**7*np.exp(0.1*5)*x2D5**-1/5)/(1+(8*10**-3*5*np.exp(-0.1*5))/(x2D5**-1)))**0.5, 'k', markersize=4, color='r',lw=1,label='SNR D=5km',zorder=0)
# ax.loglog(x2D2, (0.25)**0.5*((5*10**7*np.exp(0.1*2)*x2D2**-1/2)/(1+(8*10**-3*2*np.exp(-0.1*2))/(x2D2**-1)))**0.5, 'k', markersize=4, color='m',lw=1,label='SNR D=2km',zorder=0)
# ax.loglog(x2D1, (0.25)**0.5*((5*10**7*np.exp(0.1*1)*x2D1**-1/1)/(1+(8*10**-3*1*np.exp(-0.1*1))/(x2D1**-1)))**0.5, 'k', markersize=4, color='c',lw=1,label='SNR D=1km',zorder=0)

#following apply to auger from 4x10^-3 to 10^-2
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/20)/(1+(1.531*10**-12*20)/(x3**0.5)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/10)/(1+(1.531*10**-12*10)/(x3**0.5)))**0.5, 'k', markersize=4, color='b',lw=1,zorder=0)
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/5)/(1+(1.531*10**-12*5)/(x3**0.5)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/2)/(1+(1.531*10**-12*2)/(x3**0.5)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/1)/(1+(1.531*10**-12*1)/(x3**0.5)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)

x1=np.logspace(-9,-5.26)
x2=np.logspace(-5.26,-2.60)
x3=np.logspace(-2.6,4.43)

ax.loglog(x1, (0.25)**0.5*((0.5*10**21*np.exp(-0.4*1)*x1**3/400)/(1+(1*10**-17*400*np.exp(0.4*1))/(x1**3)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)

#9*10^-7, 0.0625
# ax.loglog(x2, ((0.2*2.874*10**15*x2**1.5/400)/(1+(3.480*10**-12*400)/(x2**1.5)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)

ax.loglog(x2, (0.25)**0.5*((0.5*5*10**15*np.exp(-0.3*1)*x2**2/400)/(1+(2*10**-12*400*np.exp(0.3*1))/(x2**2)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
#0.0625 to 0.1

ax.loglog(x3, (0.25)**0.5*((0.5*5*10**7*np.exp(0.1*1)*x3**-1/400)/(1+(2*10**-4*400*np.exp(-0.1*1))/(x3**-1)))**0.5, 'k', markersize=4, color='g',lw=1,label='JEM-EUSO',zorder=0)



leg = ax.legend(loc='upper left', shadow=True)
ax.grid(True)
plt.tight_layout()
plt.savefig('Nvscrosssection.pdf')
plt.show()
