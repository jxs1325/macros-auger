# %%
#auger plot for SNR of blackbody number of photons for fixed D = 10 km and varying v_x

from scipy.interpolate import interp1d
import io
import csv
import sys
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import scipy
import os

#Define Plot
fig = plt.figure()
ax = fig.add_subplot(111)
x=np.logspace(-7,2)
# x050=np.logspace(-9,-3.47)
x0150=np.logspace(-9,-4.53)
x0250=np.logspace(-9,-4.89)
x0350=np.logspace(-9,-5.16)
x0450=np.logspace(-9,-5.38)
# x150=np.logspace(-3.47,-0.7)
x1150=np.logspace(-4.53,-1.75)
x1250=np.logspace(-4.89,-2.1)
x1350=np.logspace(-5.16,-2.38)
x1450=np.logspace(-5.38,-2.6)
# x250=np.logspace(-0.7,4.43)
x2150=np.logspace(-1.75,4.52)
x2250=np.logspace(-2.1,4.78)
x2350=np.logspace(-2.38,5.20)
x2450=np.logspace(-2.6,6.08)
# x3D1=np.logspace(4.43,7)
# x3D2=np.logspace(4.52,7)
# x3D5=np.logspace(4.78,7)
# x3D10=np.logspace(5.20,7)
# x3D20=np.logspace(6.08,7)
#X-axis
ax.set_xlabel('$\sigma_\t{X}$ [cm$^{2}$]',fontsize=12)
ax.set_xlim([x.min(),x.max()])

#Y-axis
ymin=10**0
ymax=10**5
ax.set_ylim([ymin,ymax])
ax.set_ylabel('SNR',fontsize=12)
#SNR = 5
ax.loglog(x,5*x**0,'k',markersize=4,color='k',lw=1,zorder=0,linestyle='dashed',label='SNR = 5')

#following apply to auger for FS one bin

# ax.loglog(x0, ((6*10**20*x0**2/20)/(1+(2*10**-16*20)/(x0**2)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
# ax.loglog(x0, ((6*10**20*x0**2/10)/(1+(2*10**-16*10)/(x0**2)))**0.5, 'k', markersize=4, color='b',lw=1,zorder=0)
# ax.loglog(x0, ((6*10**20*x0**2/5)/(1+(2*10**-16*5)/(x0**2)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
# ax.loglog(x0, ((6*10**20*x0**2/2)/(1+(2*10**-16*2)/(x0**2)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
# ax.loglog(x0, ((6*10**20*x0**2/1)/(1+(2*10**-16*1)/(x0**2)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)
#ax.loglog(x050, (0.25)**0.5*((6.4*10**-5*10**21*np.exp(-0.4*10)*x050**3/10)/(1+(4*10**-16*10*np.exp(0.4*10))/(6.4*10**-5*x050**3)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
ax.loglog(x0150, (0.25)**0.5*((0.5*0.099*10**21*np.exp(-0.4*10)*x0150**3/10)/(1+(2*4*10**-16*10*np.exp(0.4*10))/(0.099*x0150**3)))**0.5, 'k', markersize=4, color='b',lw=1,zorder=0)
ax.loglog(x0250, (0.25)**0.5*((0.5*1*10**21*np.exp(-0.4*10)*x0250**3/10)/(1+(2*4*10**-16*10*np.exp(0.4*10))/(1*x0250**3)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
ax.loglog(x0350, (0.25)**0.5*((0.5*7.52*10**21*np.exp(-0.4*10)*x0350**3/10)/(1+(2*4*10**-16*10*np.exp(0.4*10))/(7.52*x0350**3)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
#ax.loglog(x0450, (0.25)**0.5*((0.5*34*10**21*np.exp(-0.4*10)*x0450**3/10)/(1+(2*4*10**-16*10*np.exp(0.4*10))/(34*x0450**3)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)

#following apply to auger from 10^-7 to 9x10^7
# ax.loglog(x1, ((3.111*10**31*x1**3.531/20)/(1+(3.214*10**-27*20)/(x1**3.531)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
# ax.loglog(x1, ((3.111*10**31*x1**3.531/10)/(1+(3.214*10**-27*10)/(x1**3.531)))**0.5, 'k', markersize=4, color='b',lw=1,zorder=0)
# ax.loglog(x1, ((3.111*10**31*x1**3.531/5)/(1+(3.214*10**-27*5)/(x1**3.531)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
# ax.loglog(x1, ((3.111*10**31*x1**3.531/2)/(1+(3.214*10**-27*2)/(x1**3.531)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
# ax.loglog(x1, ((3.111*10**31*x1**3.531/1)/(1+(3.214*10**-27*1)/(x1**3.531)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)

#ax.loglog(x150, (0.25)**0.5*((0.0016*5*10**15*np.exp(-0.3*10)*x150**2/10)/(1+(8*10**-11*10*np.exp(0.3*10))/(0.0016*x150**2)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
ax.loglog(x1150, (0.25)**0.5*((0.5*0.21*5*10**15*np.exp(-0.3*10)*x1150**2/10)/(1+(2*8*10**-11*10*np.exp(0.3*10))/(0.21*x1150**2)))**0.5, 'k', markersize=4, color='b',lw=1,zorder=0)
ax.loglog(x1250, (0.25)**0.5*((0.5*5*10**15*np.exp(-0.3*10)*x1250**2/10)/(1+(2*8*10**-11*10*np.exp(0.3*10))/(x1250**2)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
ax.loglog(x1350, (0.25)**0.5*((0.5*3.84*5*10**15*np.exp(-0.3*10)*x1350**2/10)/(1+(2*8*10**-11*10*np.exp(0.3*10))/(3.84*x1350**2)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
#ax.loglog(x1450, (0.25)**0.5*((0.5*10.5*5*10**15*np.exp(-0.3*10)*x1450**2/10)/(1+(2*8*10**-11*10*np.exp(0.3*10))/(10.5*x1450**2)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)

#following apply to auger from 3x10^-7 to 4x10^-3

# ax.loglog(x2, ((1.63*10**19*x2**1.5/20)/(1+(6.1*10**-15*20)/(x2**1.5)))**0.5, 'k', markersize=4, color='g',lw=1,label='SNR D=20km',zorder=0)
# ax.loglog(x2, ((1.63*10**19*x2**1.5/10)/(1+(6.1*10**-15*10)/(x2**1.5)))**0.5, 'k', markersize=4, color='b',lw=1,label='SNR D=10km',zorder=0)
# ax.loglog(x2, ((1.63*10**19*x2**1.5/5)/(1+(6.1*10**-15*5)/(x2**1.5)))**0.5, 'k', markersize=4, color='r',lw=1,label='SNR D=5km',zorder=0)
# ax.loglog(x2, ((1.63*10**19*x2**1.5/2)/(1+(6.1*10**-15*2)/(x2**1.5)))**0.5, 'k', markersize=4, color='m',lw=1,label='SNR D=2km',zorder=0)
# ax.loglog(x2, ((1.63*10**19*x2**1.5/1)/(1+(6.1*10**-15*1)/(x2**1.5)))**0.5, 'k', markersize=4, color='c',lw=1,label='SNR D=1km',zorder=0)

#ax.loglog(x250, (0.25)**0.5*((25*5*10**7*np.exp(0.1*10)*x250**-1/10)/(1+(8*10**-3*10*np.exp(-0.1*10))/(25*x250**-1)))**0.5, 'k', markersize=4, color='g',lw=1,label='$v_x = 50$ kms$^{-1}$',zorder=0)
ax.loglog(x2150, (0.25)**0.5*((0.5*2.16*5*10**7*np.exp(0.1*10)*x2150**-1/10)/(1+(2*8*10**-3*10*np.exp(-0.1*10))/(2.16*x2150**-1)))**0.5, 'k', markersize=4, color='b',lw=1,label='$v_x = 170$ kms$^{-1}$',zorder=0)
ax.loglog(x2250, (0.25)**0.5*((0.5*5*10**7*np.exp(0.1*10)*x2250**-1/10)/(1+(2*8*10**-3*10*np.exp(-0.1*10))/(x2250**-1)))**0.5, 'k', markersize=4, color='r',lw=1,label='$v_x = 250$ kms$^{-1}$',zorder=0)
ax.loglog(x2350, (0.25)**0.5*((0.5*0.5*5*10**7*np.exp(0.1*10)*x2350**-1/10)/(1+(2*8*10**-3*10*np.exp(-0.1*10))/(0.5*x2350**-1)))**0.5, 'k', markersize=4, color='m',lw=1,label='$v_x = 350$ kms$^{-1}$',zorder=0)
#ax.loglog(x2450, (0.25)**0.5*((0.5*0.3*5*10**7*np.exp(0.1*10)*x2450**-1/10)/(1+(2*8*10**-3*10*np.exp(-0.1*10))/(0.3*x2450**-1)))**0.5, 'k', markersize=4, color='c',lw=1,label='$v_x = 450$ kms$^{-1}$',zorder=0)

#following apply to auger from 4x10^-3 to 10^-2
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/20)/(1+(1.531*10**-12*20)/(x3**0.5)))**0.5, 'k', markersize=4, color='g',lw=1,zorder=0)
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/10)/(1+(1.531*10**-12*10)/(x3**0.5)))**0.5, 'k', markersize=4, color='b',lw=1,zorder=0)
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/5)/(1+(1.531*10**-12*5)/(x3**0.5)))**0.5, 'k', markersize=4, color='r',lw=1,zorder=0)
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/2)/(1+(1.531*10**-12*2)/(x3**0.5)))**0.5, 'k', markersize=4, color='m',lw=1,zorder=0)
# ax.loglog(x3, 0.5*((2.614*10**17*x3**0.5/1)/(1+(1.531*10**-12*1)/(x3**0.5)))**0.5, 'k', markersize=4, color='c',lw=1,zorder=0)


leg = ax.legend(loc='upper left', shadow=True)
ax.grid(True)
plt.savefig('augerbbplotvaryv.pdf')
plt.tight_layout()
plt.show()
